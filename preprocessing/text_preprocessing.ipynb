# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 42.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.5 MB/s eta 0:00:00
# ...
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16299 sha256=ab9d29180ab5cf2984283e7cf5ac807a35dcd6588a29643010ce9a2028fa9a07
#   Stored in directory: /root/.cache/pip/wheels/6c/bd/3e/2d6afc9bc36c9975f8e4215a270bbac6580c4361ebd6bb2323
# Successfully built swifter
# ...

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 20.7 MB/s eta 0:00:00
# ...

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import re
import string
import swifter

from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
# ----- Read Data -----
news_data = pd.read_csv("/content/scrapped_news.csv")
# bdm = pd.read_csv("/content/scrapped_news_bulutangkis.csv", encoding = "ISO-8859-1")
# basket = pd.read_csv("/content/scrapped_news_basket.csv", encoding = "ISO-8859-1")
# tenis = pd.read_csv("/content/scrapped_news_tenis.csv", encoding = "ISO-8859-1")
# voli = pd.read_csv("/content/scrapped_news_voli.csv", encoding = "ISO-8859-1")
# bencana =

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        10 non-null     object
#  1   date         10 non-null     object
#  2   description  10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
bdm.info()

# %%
# ----- Delete Column Date ----- 
news_data= news_data.drop('date', axis=1)

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34273 entries, 0 to 34272
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        34256 non-null  object
#  1   date         34273 non-null  object
#  2   description  34273 non-null  object
# dtypes: object(3)
# memory usage: 803.4+ KB

# %%
Dup_Rows = news_data[news_data.duplicated()]
Dup_Rows
# Out:
#                                                    title  \
# 3141   BPBD Petakan 3 Kecamatan di Puncak Bogor Rawan...
# 4354                               Bahaya di Tanah Surga
# 4463   Green Economy BSI: Gagasan Perbankan Berbasis ...
# 4722   Cuaca Ekstrem April 2023, BMKG Prediksi Terjad...
# 4727   Menengok Masjid Darussalam Cibubur, Masjid den...
# ...                                                  ...
# 34178  Pentingnya Kolaborasi untuk Cegah Ancaman Benc...
# 34185  Guru Korban Tewas Tertimpa Longsor di Depok Se...
# 34230  2.594 KK Korban Longsor Sukajaya Bogor Tunggu ...
# 34241  30 Rumah di Lebak Rusak Diterjang Angin Puting...
# 34242                   Gempa M 6,3 Guncang Papua Nugini
#
#                                  date  \
# 3141    Selasa, 21 Mar 2023 13:54 WIB
# 4354     Jumat, 25 Nov 2022 09:00 WIB
# 4463     Senin, 26 Des 2022 11:33 WIB
# 4722    Selasa, 11 Apr 2023 18:37 WIB
# 4727    Selasa, 11 Apr 2023 03:19 WIB
# ...                               ...
# ...

# %%
# ----- Delete Duplicate Data ----- 
news_data.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31251 entries, 0 to 34272
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        31235 non-null  object
#  1   date         31251 non-null  object
#  2   description  31251 non-null  object
# dtypes: object(3)
# memory usage: 976.6+ KB

# %%
news_data
# Out:
#                                                    title  \
# 0      BNI Sirnas 2023 dan Cita-cita Anak-anak RI Unj...
# 1      Soal Kamar Bocor Atlet Tim Bulutangkis RI di S...
# 2      PBSI Minta Atlet Lekas Adaptasi Cuaca di SEA G...
# 3                   Tekad Chico Lebih Fight di Tiap Laga
# 4      Vito Absen, PBSI Tetap Optimistis dengan Skuad...
# ...                                                  ...
# 34268  Titik 'Jalur Tengkorak' di Tasik: Tanjakan Str...
# 34269      Produksi Migas Anjlok, Hati-hati Impor Jebol!
# 34270       Produksi Migas RI Anjlok, Ini Biang Keroknya
# 34271  2 Rumah di Bulukerto Wonogiri Rusak Tertimpa T...
# 34272  Perbaikan Akses-Pujon Kediri Terus Dikebut Jel...
#
#                                  date  \
# 0      Selasa, 09 Mei  2023 09:15 WIB
# 1      Selasa, 09 Mei  2023 09:40 WIB
# 2       Sabtu, 06 Mei  2023 19:00 WIB
# 3       Jumat, 05 Mei  2023 16:15 WIB
# 4       Jumat, 05 Mei  2023 12:30 WIB
# ...                               ...
# ...

# %%
# ----- Case Folding -----
def change_lower_case(text):
  return text.lower()

def remove_news_special(text):
  # remove tab, new line, and back slice
  text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\'," ")
  # remove non ASCII (emoticon, kanji, .etc)
  text = text.encode('ascii', 'replace').decode('ascii')
  # remove mention, link, hashtag
  text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
  # remove incomplete url
  return text.replace("http://", " ").replace("https://", " ")

#remove number
def remove_number(text):
  return re.sub(r'[-+]?[0-9]+', '', text)

#remove punctuation
def remove_punctuation(text):
  return text.translate(str.maketrans("", "", string.punctuation))

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
  return text.strip()

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
  return re.sub('\s+',' ',text)

#remove single char
def remove_single_char(text):
  return re.sub(r"\b[a-zA-Z]\b", "", text)

# %%
news_data['description'] = news_data['description'].apply(change_lower_case)
news_data['description'] = news_data['description'].apply(remove_news_special)
news_data['description'] = news_data['description'].apply(remove_number)
news_data['description'] = news_data['description'].apply(remove_punctuation)
news_data['description'] = news_data['description'].apply(remove_whitespace_LT)
news_data['description'] = news_data['description'].apply(remove_whitespace_multiple)
news_data['description'] = news_data['description'].apply(remove_single_char)

# %%
news_data.head()
# Out:
#                                                title  \
# 0  BNI Sirnas 2023 dan Cita-cita Anak-anak RI Unj...
# 1  Soal Kamar Bocor Atlet Tim Bulutangkis RI di S...
# 2  PBSI Minta Atlet Lekas Adaptasi Cuaca di SEA G...
# 3               Tekad Chico Lebih Fight di Tiap Laga
# 4  Vito Absen, PBSI Tetap Optimistis dengan Skuad...
#
#                              date  \
# 0  Selasa, 09 Mei  2023 09:15 WIB
# 1  Selasa, 09 Mei  2023 09:40 WIB
# 2   Sabtu, 06 Mei  2023 19:00 WIB
# 3   Jumat, 05 Mei  2023 16:15 WIB
# 4   Jumat, 05 Mei  2023 12:30 WIB
#
#                                          description
# 0  ajang sudah sampai di denpasar bali ajang ini ...
# 1  tim bulutangkis indonesia yang tampil di kambo...
# 2  kepala bidang pembinaan prestasi pbsi rionny m...
# 3  bertekad tampil fight di setiap laga yang diik...
# 4  pbsi tetap optimistis dengan skuad tunggal put...

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31251 entries, 0 to 34272
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        31235 non-null  object
#  1   date         31251 non-null  object
#  2   description  31251 non-null  object
# dtypes: object(3)
# memory usage: 976.6+ KB

# %%
# ----- Stopwords Removal ----- 
nltk.download('stopwords')
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["detik", "detikjatim", "detikjateng", "detikjabar", "detiksulsel", "detiksumbar", "detikbali", "detikpapua", "detiksulteng", "detikmaluku", "detjatim", "detikcom", "allahumma", "aamiin", "allah", "bismillah", "20detik", "gambasvideo", "video", "selengkapnya"])
list_stopwords.extend(["yang","yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah', 'dkk', 
                       'senin', 'selasa', 'rabu', 'kamis', 'jumat', 'sabtu', 'minggu',
                       'januari', 'februari', 'maret', 'april', 'mei', 'juni', 'juli', 'agustus', 'september', 'oktober', 'november', 'desember'])
list_stopwords = set(list_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_stopwords(text):
    text = ' '.join(word for word in text.split() if word not in list_stopwords)
    return text
     
news_data['description_clean_stop'] = news_data['description'].apply(clean_stopwords)

# %%
news_data.head()
# Out:
#                                                title  \
# 0  BNI Sirnas 2023 dan Cita-cita Anak-anak RI Unj...
# 1  Soal Kamar Bocor Atlet Tim Bulutangkis RI di S...
# 2  PBSI Minta Atlet Lekas Adaptasi Cuaca di SEA G...
# 3               Tekad Chico Lebih Fight di Tiap Laga
# 4  Vito Absen, PBSI Tetap Optimistis dengan Skuad...
#
#                              date  \
# 0  Selasa, 09 Mei  2023 09:15 WIB
# 1  Selasa, 09 Mei  2023 09:40 WIB
# 2   Sabtu, 06 Mei  2023 19:00 WIB
# 3   Jumat, 05 Mei  2023 16:15 WIB
# 4   Jumat, 05 Mei  2023 12:30 WIB
#
#                                          description  \
# 0  ajang sudah sampai di denpasar bali ajang ini ...
# 1  tim bulutangkis indonesia yang tampil di kambo...
# 2  kepala bidang pembinaan prestasi pbsi rionny m...
# 3  bertekad tampil fight di setiap laga yang diik...
# 4  pbsi tetap optimistis dengan skuad tunggal put...
#
#                               description_clean_stop
# ...

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31251 entries, 0 to 34272
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   31235 non-null  object
#  1   date                    31251 non-null  object
#  2   description             31251 non-null  object
#  3   description_clean_stop  31251 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
# # import StemmerFactory class
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# # create stemmer
# factory = StemmerFactory()
# stemmer = factory.create_stemmer()
# # stemming process
# sentence = 'Perekonomian Indonesia sedang dalam pertumbuhan yang membanggakan'
# output   = stemmer.stem(sentence)
# print(output)
# # ekonomi indonesia sedang dalam tumbuh yang bangga
# print(stemmer.stem('Mereka meniru-nirukannya'))
# # mereka tiru

# sentence = "Programmers program with programming languages"
# words = word_tokenize(sentence)

# def stemming_word(text):
#   text = stemmer.stem(text)
#   print(text)
#   for w in text:
#     print(w, " : ", stemmer.stem(w))
#   return text

# %%
# # ----- Stemming ----- 
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming_word(text):
  text = stemmer.stem(text)
  print(text)
  return text
   
news_data['description_clean_stem'] = news_data['description_clean_stop'].apply(stemming_word)
# news_data['description_clean_stem'] = news_data['description_clean'].stemmer.stem(text)
# Out:
# ribu warga desa camat sukajaya kabupaten bogor jawa barat jabar korban tanah longsor tempat rumah huni huntara harap perintah realisasi huni huntap ganti rumah rusak dampak longsor catat keluarga tempat huntara peristiwa tanah longsor camat sukajaya bencana catat keluarga dampak langsung desa desa cileuksa milik huntap kemarin huntap desa urug huntap sekretaris camat sekcam sukajaya tirta juwarta informasi bangun huntap ambil desa cisarua sisa desa cileuksa desa pasir madang sepakat perata lahan tirta sembilan desa dampak longsor aju lokasilokasi bangun huntap ditindaklanjuti pemkab bogor uji layak aman lokasi bangun huntap ditindaklanjuti desa desa cileuksa titik lokasi huntap desa pasirmadang titik desa cisarua titik sisa tunggu harap ayom bangun huntap tirta ribu warga huni huntara desa ganti rumah rusak tempat lokasi rawan dampak longsor kondisi huntara tempat bangun ada bangun kondisi rusak dampak bencana angin puting beliung pemkab bogor aju huni perintah pusat bnpb provinsi ja
# ...

# %%
news_data.head()

# %%
news_data.info()

# %%
news_stop = news_data['description_clean_stop']
# news_stem = news_data['description_clean_stem']

# %%
news_stop.head()

# %%
news_stop.info()

# %%
news_data.to_csv('text_preprocessing_stop.csv')

# %%
news_stop.to_csv('sport_stop.csv')
# news_stem.to_csv('sport_stem.csv')

# %%
# ----- Merge Data -----
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv_files

# %%
# ----- Merge Data -----
news_data = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            news_data = news_data.append(df_temp, ignore_index=True)
news_data

# %%
# ----- Change File CVS to TXT ----- 
import csv
csv_file = input('Enter the name of your input file: ')
txt_file = input('Enter the name of your output file: ')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# Enter the name of your input file: sport_stop.csv
# Enter the name of your output file: text_prerocessing_stop.txt

# %%
# # ----- Tokenizing -----
# #NLTK word tokenize 
# def word_tokenize_wrapper(text):
#     return word_tokenize(text)

# #NLTK calc frequency distribution
# def freqDist_wrapper(text):
#     return FreqDist(text)

# nltk.download('punkt')
# # print(news_data['description'].isnull())
# # print(news_data['description'].isnull())
# news_data['description_tokens'] = news_data['description'].apply(word_tokenize_wrapper)
# news_data['description_tokens_fdist'] = news_data['description_tokens'].apply(freqDist_wrapper)

# %%
news_data

# %%
# nltk.download('stopwords')
# def stopwords_removal(words):
#   list_stopwords = stopwords.words('indonesian')
#   list_stopwords.extend(["detik", "detikjatim", "detikjateng", "detikjabar", "detiksulsel", "detiksumbar", "detikbali", "detikpapua", "detiksulteng", "detikmaluku", "detjatim", "detikcom", "allahumma", "aamiin", "allah", "bismillah", "20detik", "gambasvideo"])
#   list_stopwords.extend(["yang","yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
#                        'kalo', 'amp', 'biar', 'bikin', 'bilang', 
#                        'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
#                        'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
#                        'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
#                        'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
#                        '&amp', 'yah'])
#   list_stopwords = set(list_stopwords)

#   return [word for word in words 
#           if word not in list_stopwords]

# %%
# list_stopwords = stopwords.words('indonesian')
# list_stopwords

# %%
# news_data['description_stop'] = news_data['description_tokens_fdist'].apply(stopwords_removal)
# news_data['description_stop_tok'] = news_data['description_tokens'].apply(stopwords_removal)

# %%
news_data.info()

# %%
# news_data= news_data.drop('description_tokens_fdist', axis=1)
# news_data= news_data.drop('description_tokens', axis=1)
# news_data= news_data.drop('description', axis=1)
# news_data= news_data.drop('title', axis=1)

# %%
# cl_data = news_data['description_stop_tok'].head(1)

# %%
# def rejoin_token(text):
#   return text.replace(" '","'").replace(" : ",': ')
 
# clean_data = clean_data.apply(rejoin_token)

# %%
# class CustomStemmer:
#   def __init__(self, tweet_data):
#       self.factory = StemmerFactory()
#       self.stemmer = self.factory.create_stemmer()
#       self.term_dict = {}
#       for document in tweet_data:
#         for term in document:
#           if term not in self.term_dict:
#             self.term_dict[term] = ''

#       for term in self.term_dict:
#         self.term_dict[term] = self.stemmed_wrapper(term)
#         print(term,":" , self.term_dict[term])

#   def stemmed_wrapper(self, term):
#     return self.stemmer.stem(term)

#   def get_stemmed_term(self, document):
#     return [self.term_dict[term] for term in document]


# stemmer = CustomStemmer(news_data['description_clean'])
# news_data['description_stemmed'] = news_data['description_clean'].swifter.apply(stemmer.get_stemmed_term)

# %%
# stemmer = CustomStemmer(news_data['description_clean'])
# news_data['description_stemmed'] = news_data['description_clean'].swifter.apply(stemmer.get_stemmed_term)
# # news_data['description_tokens_stemmed_tok'] = news_data['description_stop_tok'].swifter.apply(stemmer.get_stemmed_term)
# We will skip normalization word

# %%
# news_data

# %%
# news_data= news_data.drop('description_tokens_fdist', axis=1)
# news_data= news_data.drop('description_tokens_wsw', axis=1)

# %%
# news_data

# %%
# nltk.download('perluniprops')

# %%
# pip install -U sacremoses

# %%
# for row in news_data['description_tokens_stemmed']:
  # print(row[0])

# %%
# from mosestokenizer import MosesDetokenizer

# with MosesDetokenizer() as detokenize:
#   detokenize(news_data['description_stop_tok'])

# %%
# news_data['description_detokens'] = detokenizer.detokenize(news_data['description_tokens_stemmed'], return_str=True)

# %%
# news_data

# %%
# from nltk.tokenize.treebank import TreebankWordDetokenizer
# # toks = ['hello', ',', 'i', 'ca', "n't", 'feel', 'my', 'feet', '!', 'Help', '!', '!']

# toks = news_data['description_tokens_stemmed']
# twd = TreebankWordDetokenizer()
# twd.detokenize(toks)

# %%
# import re
# def untokenize(words):
#     """
#     Untokenizing a text undoes the tokenizing operation, restoring
#     punctuation and spaces to the places that people expect them to be.
#     Ideally, `untokenize(tokenize(text))` should be identical to `text`,
#     except for line breaks.
#     """
#     text = ' '.join(words)
#     step1 = text.replace("`` ", '"').replace(" ''", '"').replace('. . .',  '...')
#     step2 = step1.replace(" ( ", " (").replace(" ) ", ") ")
#     step3 = re.sub(r' ([.,:;?!%]+)([ \'"`])', r"\1\2", step2)
#     step4 = re.sub(r' ([.,:;?!%]+)$', r"\1", step3)
#     step5 = step4.replace(" '", "'").replace(" n't", "n't").replace(
#          "can not", "cannot")
#     step6 = step5.replace(" ` ", " '")
#     return step6.strip()

# %%
# tokenized = ['I', "'ve", 'found', 'a', 'medicine', 'for', 'my','disease', '.']
# untokenize(tokenized)
# # tokenized = 
# untokenize(news_data['description_tokens_stemmed'].head(1))
# news_data['description_tokens_stemmed']

# %%
# text_pre = pd.read_csv("/content/text_preprocessing1.csv")

# %%
# text_pre = text_pre.drop('Unnamed: 0', axis=1)

# %%
# text_pre['description_tokens_stemmed']

# %%
# clean_data = news_data['description_tokens_stemmed']

# %%
# clean_data.to_csv('clean_data.csv')

# %%
# cl_dt = pd.read_csv("/content/clean_data.csv")

# %%
# def rejoin_token(text):
#   return text.replace(" '","'").replace(" : ",': ')
 
# clean_data = clean_data.apply(rejoin_token)

# %%
# clean_data = clean_data.apply(rejoin_token)
